# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sqlalchemy import create_engine
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import ComplementNB,MultinomialNB,BernoulliNB
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report,accuracy_score,f1_score

nltk.download('punkt') #tokenizer
nltk.download('stopwords') 
nltk.download('wordnet')# lemmatizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/clairegong/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/clairegong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/clairegong/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql('SELECT * FROM messages', engine)

# %%
df.head(1)
# Out:
#                                              message   genre  related  \
# 0  Weather update - a cold front from Cuba that c...  direct        1
#
#    request  offer  aid_related  medical_help  medical_products  \
# 0        0      0            0             0                 0
#
#    search_and_rescue  security  ...  aid_centers  other_infrastructure  \
# 0                  0         0  ...            0                     0
#
#    weather_related  floods  storm  fire  earthquake  cold  other_weather  \
# 0                0       0      0     0           0     0              0
#
#    direct_report
# 0              0
#
# [1 rows x 38 columns]

# %%
# load data from database
# later i found because my process_data.py is a bit different from the notebook version 
#so database is one column different...

def load_data():
    engine = create_engine('sqlite:///DisasterResponse.db')
    df = pd.read_sql('SELECT * FROM messages', engine)
    X = df.message.values
    Y = df.iloc[:,2:].values
#     labels=df.iloc[:,2:].columns
    return X,Y#,labels

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %% [markdown]
#  #### Three useful methods of  text feature extraction. I don't know when to use each yet.
#
# CountVectorizer - Bag of Words
#
# **TfidfTransformer - TF-IDF values**
#
# TfidfVectorizer - Bag of Words AND TF-IDF values

# %%
def tokenize(text):
    # normalize case and remove punctuation
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # tokenize text
    tokens = word_tokenize(text)
    
    # lemmatize and remove stop words
    lemmatizer = WordNetLemmatizer()
    stop_words = stopwords.words("english")
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]

    return tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
def make_pipe(clf):
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', clf)
     ])
    return pipeline

# %%
def build_model(clf):
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', clf)
     ])
        
    parameters = {
        'vect__ngram_range': ((1, 1), (1, 2)),
        'vect__max_df': (0.5, 0.75, 1.0),
        'tfidf__use_idf': (True, False)
    }

    cv = GridSearchCV(pipeline, param_grid=parameters, cv=3)

    return cv

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
labels=df.columns[2:].tolist()
def report(Y_test,Y_preds,labels=labels):
    for i in range(36):
        print(classification_report(Y_test[:,i], Y_preds[:,i]),('for label:'+labels[i].upper()))
#Macro-Average: (class1 + class2+...)/no_class	 #treat classes equally; 
#Micro-Average: total_true/total	#treat instances equally, so classes with larger dataset carry more weight

# %%
def multi_f1(Y_test,Y_preds):
    f1_list_weighted=[f1_score(Y_test[:,i], Y_preds[:,i], average='weighted')for i in range(36)]
    print('weighted f1_score',sum(f1_list_weighted)/36)

# %% [markdown]
# ### 6. Improve your model/GridSearch
# Use grid search to find better parameters.

# %%
multi_clf=MultiOutputClassifier(ComplementNB())

def main_cv(clf=multi_clf):
    X, Y = load_data()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

    model=build_model(clf)

    # train classifier
    model.fit(X_train, Y_train)
    print(model.best_params_)

    # predict on test data
    Y_preds = model.predict(X_test)

    # display averaged f1_score
    multi_f1(Y_test,Y_preds)


# main_cv()

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
def main(clf=multi_clf):
    X, Y = load_data()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

    pipe=make_pipe(clf)

    # train classifier
    pipe.fit(X_train, Y_train)

    # predict on test data
    Y_preds = pipe.predict(X_test)

    # display averaged f1_score
    multi_f1(Y_test,Y_preds)
    return pipe,X_test,Y_test,Y_preds


pipe,X_test,Y_test,Y_preds=main()
# Out:
# weighted f1_score 0.9244240538281583

# %%
report(Y_test,Y_preds)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.42      0.54      1548
#            1       0.84      0.95      0.89      4956
#            2       0.51      0.48      0.49        50
#
#     accuracy                           0.82      6554
#    macro avg       0.70      0.62      0.64      6554
# weighted avg       0.81      0.82      0.81      6554
#  for label:RELATED
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92      5423
#            1       0.63      0.59      0.61      1131
#
#     accuracy                           0.87      6554
#    macro avg       0.77      0.76      0.77      6554
# weighted avg       0.87      0.87      0.87      6554
#  for label:REQUEST
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      6525
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#  for label:OFFER
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78      3814
#            1       0.68      0.75      0.72      2740
#
#     accuracy                           0.75      6554
#    macro avg       0.75      0.75      0.75      6554
# weighted avg       0.76      0.75      0.75      6554
#  for label:AID_RELATED
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      6001
#            1       0.39      0.13      0.20       553
#
#     accuracy                           0.91      6554
#    macro avg       0.66      0.56      0.58      6554
# weighted avg       0.88      0.91      0.89      6554
#  for label:MEDICAL_HELP
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6231
#            1       0.28      0.11      0.16       323
#
#     accuracy                           0.94      6554
#    macro avg       0.62      0.55      0.56      6554
# weighted avg       0.92      0.94      0.93      6554
#  for label:MEDICAL_PRODUCTS
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6387
#            1       0.02      0.01      0.01       167
#
#     accuracy                           0.97      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.95      0.97      0.96      6554
#  for label:SEARCH_AND_RESCUE
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6440
#            1       0.00      0.00      0.00       114
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.49      6554
# weighted avg       0.97      0.98      0.97      6554
#  for label:SECURITY
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      6350
#            1       0.41      0.23      0.29       204
#
#     accuracy                           0.97      6554
#    macro avg       0.69      0.61      0.64      6554
# weighted avg       0.96      0.97      0.96      6554
#  for label:MILITARY
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#  for label:CHILD_ALONE
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      6136
#            1       0.42      0.16      0.23       418
#
#     accuracy                           0.93      6554
#    macro avg       0.68      0.57      0.60      6554
# weighted avg       0.91      0.93      0.92      6554
#  for label:WATER
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      5813
#            1       0.54      0.34      0.41       741
#
#     accuracy                           0.89      6554
#    macro avg       0.73      0.65      0.68      6554
# weighted avg       0.88      0.89      0.88      6554
#  for label:FOOD
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      5977
#            1       0.47      0.20      0.29       577
#
#     accuracy                           0.91      6554
#    macro avg       0.70      0.59      0.62      6554
# weighted avg       0.89      0.91      0.89      6554
#  for label:SHELTER
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6462
#            1       0.27      0.22      0.24        92
#
#     accuracy                           0.98      6554
#    macro avg       0.63      0.60      0.62      6554
# weighted avg       0.98      0.98      0.98      6554
#  for label:CLOTHING
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6417
#            1       0.02      0.01      0.01       137
#
#     accuracy                           0.97      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.96      0.97      0.97      6554
#  for label:MONEY
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6478
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#  for label:MISSING_PEOPLE
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6333
#            1       0.09      0.02      0.04       221
#
#     accuracy                           0.96      6554
#    macro avg       0.53      0.51      0.51      6554
# weighted avg       0.94      0.96      0.95      6554
#  for label:REFUGEES
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6259
#            1       0.29      0.08      0.13       295
#
#     accuracy                           0.95      6554
#    macro avg       0.63      0.54      0.55      6554
# weighted avg       0.93      0.95      0.94      6554
#  for label:DEATH
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      5664
#            1       0.16      0.03      0.04       890
#
#     accuracy                           0.85      6554
#    macro avg       0.51      0.50      0.48      6554
# weighted avg       0.77      0.85      0.80      6554
#  for label:OTHER_AID
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      6125
#            1       0.02      0.00      0.01       429
#
#     accuracy                           0.92      6554
#    macro avg       0.48      0.50      0.48      6554
# weighted avg       0.87      0.92      0.90      6554
#  for label:INFRASTRUCTURE_RELATED
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6262
#            1       0.17      0.05      0.08       292
#
#     accuracy                           0.95      6554
#    macro avg       0.56      0.52      0.53      6554
# weighted avg       0.92      0.95      0.93      6554
#  for label:TRANSPORT
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6205
#            1       0.31      0.09      0.13       349
#
#     accuracy                           0.94      6554
#    macro avg       0.63      0.54      0.55      6554
# weighted avg       0.92      0.94      0.93      6554
#  for label:BUILDINGS
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6428
#            1       0.07      0.03      0.04       126
#
#     accuracy                           0.97      6554
#    macro avg       0.53      0.51      0.52      6554
# weighted avg       0.96      0.97      0.97      6554
#  for label:ELECTRICITY
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6513
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#  for label:TOOLS
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6484
#            1       0.00      0.00      0.00        70
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#  for label:HOSPITALS
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      6528
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#  for label:SHOPS
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6477
#            1       0.00      0.00      0.00        77
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#  for label:AID_CENTERS
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6264
#            1       0.03      0.01      0.01       290
#
#     accuracy                           0.95      6554
#    macro avg       0.49      0.50      0.49      6554
# weighted avg       0.91      0.95      0.93      6554
#  for label:OTHER_INFRASTRUCTURE
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      4726
#            1       0.71      0.66      0.68      1828
#
#     accuracy                           0.83      6554
#    macro avg       0.79      0.78      0.78      6554
# weighted avg       0.83      0.83      0.83      6554
#  for label:WEATHER_RELATED
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      6003
#            1       0.53      0.23      0.32       551
#
#     accuracy                           0.92      6554
#    macro avg       0.73      0.61      0.64      6554
# weighted avg       0.90      0.92      0.90      6554
#  for label:FLOODS
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      5944
#            1       0.61      0.37      0.46       610
#
#     accuracy                           0.92      6554
#    macro avg       0.77      0.67      0.71      6554
# weighted avg       0.91      0.92      0.91      6554
#  for label:STORM
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6476
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#  for label:FIRE
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      5975
#            1       0.68      0.42      0.52       579
#
#     accuracy                           0.93      6554
#    macro avg       0.81      0.70      0.74      6554
# weighted avg       0.92      0.93      0.92      6554
#  for label:EARTHQUAKE
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6425
#            1       0.08      0.03      0.04       129
#
#     accuracy                           0.97      6554
#    macro avg       0.53      0.51      0.52      6554
# weighted avg       0.96      0.97      0.97      6554
#  for label:COLD
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6208
#            1       0.16      0.03      0.06       346
#
#     accuracy                           0.94      6554
#    macro avg       0.56      0.51      0.51      6554
# weighted avg       0.91      0.94      0.92      6554
#  for label:OTHER_WEATHER
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      5259
#            1       0.59      0.51      0.55      1295
#
#     accuracy                           0.83      6554
#    macro avg       0.74      0.71      0.72      6554
# weighted avg       0.83      0.83      0.83      6554
#  for label:DIRECT_REPORT

# %%
# code for calculating other metrics
# # compute scores for each class
accuracy_list=[accuracy_score(Y_test[:,i], Y_preds[:,i])for i in range(36)]
# f1_list_micro=[f1_score(Y_test[:,i], Y_preds[:,i], average='micro')for i in range(36)]#same value as accuracy
# f1_list_macro=[f1_score(Y_test[:,i], Y_preds[:,i], average='macro')for i in range(36)]

print('average accuracy:',sum(accuracy_list)/36)
# print('micro f1_score',sum(f1_list_micro)/36)

# #macro treat class equally, thus not suitable for imbalanced class
# print('macro f1_score',sum(f1_list_macro)/36)
# Out:
# average accuracy: 0.9339843352659953

# %%
score_df=pd.DataFrame({'accuracy':accuracy_list},index=labels)
score_df.head()
# Out:
#               accuracy
# related       0.823924
# request       0.870156
# offer         0.989930
# aid_related   0.750534
# medical_help  0.909216

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
from sklearn.naive_bayes import ComplementNB,MultinomialNB,BernoulliNB,GaussianNB
#1st model cannot import in Udacity workspace, 2nd trigger warning, third is as good as first
#GaussianNB cannot take sparse matrix
NB_clf_2=MultiOutputClassifier(BernoulliNB(alpha=0.6))
_,_,_,_=main(NB_clf_2)
#alpha=1.0 0.9255590554451469; 0.7, 0.9274249838428733;0.6,0.9276770612976315;
#0.5, 0.9275877839959503; 0.3, 0.9268416314997615
# Out:
# weighted f1_score 0.9276770612976315

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
from joblib import dump, load
#save
dump(pipe, 'pipe.pkl')
#load
pipe_load = load('pipe.pkl')

# %%
# check that pipeline saved sucessfully

Y_preds_load=pipe_load.predict(X_test)
import numpy
numpy.mean(Y_preds_load==Y_preds)
# Out:
# 1.0

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.

# %%
df.head(1)
# Out:
#                                              message   genre  related  \
# 0  Weather update - a cold front from Cuba that c...  direct        1
#
#    request  offer  aid_related  medical_help  medical_products  \
# 0        0      0            0             0                 0
#
#    search_and_rescue  security  ...  aid_centers  other_infrastructure  \
# 0                  0         0  ...            0                     0
#
#    weather_related  floods  storm  fire  earthquake  cold  other_weather  \
# 0                0       0      0     0           0     0              0
#
#    direct_report
# 0              0
#
# [1 rows x 38 columns]

# %%
text=["i hear thunder"]
def display_category(text,model=pipe):
    # display prediction of a message in dataframe format
    cat=model.predict(text)[0]
    df=pd.DataFrame({'prediction': cat}, index=labels)
    df= df[df.prediction==1]
    return df
display_category(text)
# Out:
#                  prediction
# related                   1
# weather_related           1
# storm                     1
# direct_report             1
